# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import seaborn as sns
import random
import pathlib

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.applications import MobileNet

# %%
from google.colab import drive
drive._mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/dataset-original.zip" -d "/content/drive/MyDrive"

# %%
strategy = tf.distribute.MirroredStrategy()

print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of devices: 1

# %%
base_dir = '/content/drive/MyDrive/trash_dataset'
dataset = pathlib.Path(base_dir)
print(str(dataset))
# Out:
# /content/drive/MyDrive/trash_dataset

# %%
train_dir = str(dataset) + '/train'
test_dir = str(dataset) + '/test'
data_train = pathlib.Path(train_dir)
data_test = pathlib.Path(test_dir)

print(str(data_train))
print(str(data_test))
# Out:
# /content/drive/MyDrive/trash_dataset/train
# /content/drive/MyDrive/trash_dataset/test

# %%
class_names = np.array(tf.io.gfile.listdir(str(data_train)))
class_names = class_names[class_names != '.DS_Store']
print(class_names)
# Out:
# ['paper' 'metal' 'plastic' 'glass' 'trash' 'cardboard']

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2700 files belonging to 6 classes.
# Using 2160 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2700 files belonging to 6 classes.
# Using 540 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
def get_label(file_path):
  parts = tf.strings.split(file_path, os.path.sep)
  one_hot = parts[-2] == class_names
  return tf.argmax(one_hot)

# %%
def get_image(file_path):
  img = tf.io.read_file(file_path)
  img = tf.io.decode_jpeg(img, channels=3)
  img = tf.image.resize(img, [img_height, img_width])
  return img

# %%
def get_img_and_label(file_path):
  label = get_label(file_path)
  img = get_image(file_path)
  return img, label

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomRotation(factor=0.15),
    layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
    layers.RandomFlip(),
    layers.RandomContrast(factor=0.1)
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
def pre_process(image_files):
  files_ds = tf.data.Dataset.from_tensor_slices(image_files)
  image_ds = files_ds.map(map_func=get_img_and_label, num_parallel_calls=AUTOTUNE)
  return image_ds

# %%
num_classes = len(class_names)
print(num_classes)
# Out:
# 6

# %%
from tensorflow.keras.optimizers import Adam

with strategy.scope():
  inputs = layers.Input(shape=(img_height, img_width, 3))
  x = data_augmentation(inputs)
  x = tf.keras.applications.mobilenet.preprocess_input(x, data_format=None)
  outputs = MobileNet(include_top=True, weights=None, classes=num_classes)(x)
  model = tf.keras.Model(inputs, outputs)

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  mobilenet_1.00_224 (Functio  (None, 6)                3235014
#  nal)
#
# =================================================================
# Total params: 3,235,014
# Trainable params: 3,213,126
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
epochs = 100
hist = model.fit(train_ds, 
                 epochs=epochs, 
                 validation_data=val_ds)
# Out:
# Epoch 1/100
# 68/68 [==============================] - 341s 2s/step - loss: 1.5364 - accuracy: 0.3949 - val_loss: 1.9090 - val_accuracy: 0.1667
# Epoch 2/100
# 68/68 [==============================] - 31s 456ms/step - loss: 1.2985 - accuracy: 0.4968 - val_loss: 2.0166 - val_accuracy: 0.1759
# Epoch 3/100
# 68/68 [==============================] - 31s 455ms/step - loss: 1.1671 - accuracy: 0.5713 - val_loss: 2.1179 - val_accuracy: 0.1667
# Epoch 4/100
# 68/68 [==============================] - 31s 455ms/step - loss: 1.0996 - accuracy: 0.5861 - val_loss: 2.1043 - val_accuracy: 0.1667
# Epoch 5/100
# 68/68 [==============================] - 31s 454ms/step - loss: 1.0067 - accuracy: 0.6255 - val_loss: 2.3739 - val_accuracy: 0.1667
# Epoch 6/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.9116 - accuracy: 0.6657 - val_loss: 2.4539 - val_accuracy: 0.1667
# Epoch 7/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.9164 - accuracy: 0.6634 - val_loss: 2.7887 - val_accuracy: 0.1519
# Epoch 8/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.8650 - accuracy: 0.6815 - val_loss: 2.2323 - val_accuracy: 0.2333
# Epoch 9/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.7893 - accuracy: 0.7125 - val_loss: 2.0472 - val_accuracy: 0.1889
# Epoch 10/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.7512 - accuracy: 0.7259 - val_loss: 1.5395 - val_accuracy: 0.4778
# Epoch 11/100
# 68/68 [==============================] - 31s 458ms/step - loss: 0.7281 - accuracy: 0.7361 - val_loss: 1.0201 - val_accuracy: 0.6389
# Epoch 12/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.6924 - accuracy: 0.7444 - val_loss: 1.4874 - val_accuracy: 0.5852
# Epoch 13/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.6605 - accuracy: 0.7569 - val_loss: 2.0304 - val_accuracy: 0.5315
# Epoch 14/100
# 68/68 [==============================] - 31s 454ms/step - loss: 0.6341 - accuracy: 0.7745 - val_loss: 1.2169 - val_accuracy: 0.6648
# Epoch 15/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.6026 - accuracy: 0.7856 - val_loss: 1.9047 - val_accuracy: 0.5481
# Epoch 16/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.5766 - accuracy: 0.7972 - val_loss: 1.8665 - val_accuracy: 0.5722
# Epoch 17/100
# 68/68 [==============================] - 31s 458ms/step - loss: 0.5766 - accuracy: 0.8005 - val_loss: 2.4022 - val_accuracy: 0.5389
# Epoch 18/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.4721 - accuracy: 0.8296 - val_loss: 1.9201 - val_accuracy: 0.5574
# Epoch 19/100
# 68/68 [==============================] - 31s 460ms/step - loss: 0.5157 - accuracy: 0.8088 - val_loss: 1.4388 - val_accuracy: 0.5889
# Epoch 20/100
# 68/68 [==============================] - 31s 460ms/step - loss: 0.4878 - accuracy: 0.8171 - val_loss: 1.2836 - val_accuracy: 0.6981
# Epoch 21/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.4525 - accuracy: 0.8375 - val_loss: 1.8338 - val_accuracy: 0.5833
# Epoch 22/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.4353 - accuracy: 0.8435 - val_loss: 1.3442 - val_accuracy: 0.6389
# Epoch 23/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.4495 - accuracy: 0.8472 - val_loss: 2.0838 - val_accuracy: 0.4852
# Epoch 24/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.4054 - accuracy: 0.8546 - val_loss: 1.1417 - val_accuracy: 0.7333
# Epoch 25/100
# 68/68 [==============================] - 31s 459ms/step - loss: 0.3917 - accuracy: 0.8546 - val_loss: 1.3739 - val_accuracy: 0.7167
# Epoch 26/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.3993 - accuracy: 0.8602 - val_loss: 1.0269 - val_accuracy: 0.6963
# Epoch 27/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.3534 - accuracy: 0.8745 - val_loss: 1.2661 - val_accuracy: 0.6926
# Epoch 28/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.3963 - accuracy: 0.8546 - val_loss: 2.3110 - val_accuracy: 0.5833
# Epoch 29/100
# 68/68 [==============================] - 31s 458ms/step - loss: 0.3868 - accuracy: 0.8560 - val_loss: 2.0338 - val_accuracy: 0.5944
# Epoch 30/100
# 68/68 [==============================] - 31s 454ms/step - loss: 0.3209 - accuracy: 0.8852 - val_loss: 1.8161 - val_accuracy: 0.6019
# Epoch 31/100
# 68/68 [==============================] - 31s 453ms/step - loss: 0.3272 - accuracy: 0.8838 - val_loss: 3.3341 - val_accuracy: 0.5111
# Epoch 32/100
# 68/68 [==============================] - 31s 453ms/step - loss: 0.3281 - accuracy: 0.8815 - val_loss: 1.7321 - val_accuracy: 0.6574
# Epoch 33/100
# 68/68 [==============================] - 31s 454ms/step - loss: 0.3498 - accuracy: 0.8861 - val_loss: 1.4618 - val_accuracy: 0.7148
# Epoch 34/100
# 68/68 [==============================] - 31s 453ms/step - loss: 0.3001 - accuracy: 0.8898 - val_loss: 1.2421 - val_accuracy: 0.7111
# Epoch 35/100
# 68/68 [==============================] - 31s 454ms/step - loss: 0.2762 - accuracy: 0.8991 - val_loss: 1.0250 - val_accuracy: 0.7278
# Epoch 36/100
# 68/68 [==============================] - 31s 453ms/step - loss: 0.3044 - accuracy: 0.8903 - val_loss: 1.8406 - val_accuracy: 0.5926
# Epoch 37/100
# 68/68 [==============================] - 31s 454ms/step - loss: 0.3054 - accuracy: 0.8949 - val_loss: 1.4764 - val_accuracy: 0.6833
# Epoch 38/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.2637 - accuracy: 0.9088 - val_loss: 1.0575 - val_accuracy: 0.7185
# Epoch 39/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.2477 - accuracy: 0.9097 - val_loss: 1.2357 - val_accuracy: 0.7315
# Epoch 40/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.2364 - accuracy: 0.9181 - val_loss: 0.9570 - val_accuracy: 0.7241
# Epoch 41/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.2455 - accuracy: 0.9153 - val_loss: 1.5981 - val_accuracy: 0.6611
# Epoch 42/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.2553 - accuracy: 0.9088 - val_loss: 1.4807 - val_accuracy: 0.6611
# Epoch 43/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.2510 - accuracy: 0.9181 - val_loss: 1.1493 - val_accuracy: 0.7481
# Epoch 44/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.2270 - accuracy: 0.9125 - val_loss: 1.5673 - val_accuracy: 0.6407
# Epoch 45/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.2159 - accuracy: 0.9264 - val_loss: 0.6811 - val_accuracy: 0.8278
# Epoch 46/100
# 68/68 [==============================] - 31s 454ms/step - loss: 0.1796 - accuracy: 0.9347 - val_loss: 1.1233 - val_accuracy: 0.7667
# Epoch 47/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.2144 - accuracy: 0.9204 - val_loss: 2.3357 - val_accuracy: 0.5778
# Epoch 48/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.2286 - accuracy: 0.9181 - val_loss: 1.3188 - val_accuracy: 0.7315
# Epoch 49/100
# 68/68 [==============================] - 31s 459ms/step - loss: 0.1986 - accuracy: 0.9273 - val_loss: 0.6794 - val_accuracy: 0.8185
# Epoch 50/100
# 68/68 [==============================] - 31s 460ms/step - loss: 0.1575 - accuracy: 0.9458 - val_loss: 1.9054 - val_accuracy: 0.6556
# Epoch 51/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.1595 - accuracy: 0.9407 - val_loss: 1.1155 - val_accuracy: 0.7407
# Epoch 52/100
# 68/68 [==============================] - 31s 458ms/step - loss: 0.1709 - accuracy: 0.9375 - val_loss: 1.5619 - val_accuracy: 0.6759
# Epoch 53/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.2003 - accuracy: 0.9255 - val_loss: 1.7186 - val_accuracy: 0.6074
# Epoch 54/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.2652 - accuracy: 0.9088 - val_loss: 1.6671 - val_accuracy: 0.6741
# Epoch 55/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.2196 - accuracy: 0.9208 - val_loss: 1.1112 - val_accuracy: 0.7481
# Epoch 56/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.1549 - accuracy: 0.9449 - val_loss: 1.2033 - val_accuracy: 0.7519
# Epoch 57/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.1368 - accuracy: 0.9546 - val_loss: 0.7058 - val_accuracy: 0.8370
# Epoch 58/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.1379 - accuracy: 0.9500 - val_loss: 0.6805 - val_accuracy: 0.8111
# Epoch 59/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.1254 - accuracy: 0.9574 - val_loss: 0.7272 - val_accuracy: 0.8074
# Epoch 60/100
# 68/68 [==============================] - 31s 459ms/step - loss: 0.1333 - accuracy: 0.9546 - val_loss: 1.8434 - val_accuracy: 0.6333
# Epoch 61/100
# 68/68 [==============================] - 31s 460ms/step - loss: 0.1441 - accuracy: 0.9486 - val_loss: 1.5184 - val_accuracy: 0.7593
# Epoch 62/100
# 68/68 [==============================] - 31s 454ms/step - loss: 0.1819 - accuracy: 0.9324 - val_loss: 1.2284 - val_accuracy: 0.7222
# Epoch 63/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.1506 - accuracy: 0.9458 - val_loss: 0.9347 - val_accuracy: 0.8056
# Epoch 64/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.1339 - accuracy: 0.9532 - val_loss: 2.2624 - val_accuracy: 0.6241
# Epoch 65/100
# 68/68 [==============================] - 31s 458ms/step - loss: 0.1204 - accuracy: 0.9537 - val_loss: 1.2335 - val_accuracy: 0.7704
# Epoch 66/100
# 68/68 [==============================] - 31s 459ms/step - loss: 0.1354 - accuracy: 0.9528 - val_loss: 1.0971 - val_accuracy: 0.7870
# Epoch 67/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.1303 - accuracy: 0.9546 - val_loss: 0.7892 - val_accuracy: 0.8259
# Epoch 68/100
# 68/68 [==============================] - 31s 458ms/step - loss: 0.1322 - accuracy: 0.9519 - val_loss: 1.7238 - val_accuracy: 0.6870
# Epoch 69/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.1133 - accuracy: 0.9616 - val_loss: 1.5102 - val_accuracy: 0.6963
# Epoch 70/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.1130 - accuracy: 0.9579 - val_loss: 1.6495 - val_accuracy: 0.7056
# Epoch 71/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.1132 - accuracy: 0.9583 - val_loss: 0.9829 - val_accuracy: 0.8037
# Epoch 72/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.1226 - accuracy: 0.9505 - val_loss: 1.0833 - val_accuracy: 0.8037
# Epoch 73/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.1254 - accuracy: 0.9579 - val_loss: 1.0966 - val_accuracy: 0.7444
# Epoch 74/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.1293 - accuracy: 0.9542 - val_loss: 2.3615 - val_accuracy: 0.6667
# Epoch 75/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.1261 - accuracy: 0.9523 - val_loss: 0.9979 - val_accuracy: 0.8167
# Epoch 76/100
# 68/68 [==============================] - 31s 459ms/step - loss: 0.0983 - accuracy: 0.9611 - val_loss: 1.4753 - val_accuracy: 0.7815
# Epoch 77/100
# 68/68 [==============================] - 31s 458ms/step - loss: 0.1517 - accuracy: 0.9500 - val_loss: 1.4936 - val_accuracy: 0.6963
# Epoch 78/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.1543 - accuracy: 0.9449 - val_loss: 0.9045 - val_accuracy: 0.8241
# Epoch 79/100
# 68/68 [==============================] - 31s 458ms/step - loss: 0.1154 - accuracy: 0.9574 - val_loss: 1.2987 - val_accuracy: 0.7574
# Epoch 80/100
# 68/68 [==============================] - 31s 459ms/step - loss: 0.1089 - accuracy: 0.9602 - val_loss: 1.1590 - val_accuracy: 0.7574
# Epoch 81/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.1256 - accuracy: 0.9602 - val_loss: 2.5848 - val_accuracy: 0.6463
# Epoch 82/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.1219 - accuracy: 0.9611 - val_loss: 0.7918 - val_accuracy: 0.8056
# Epoch 83/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.0863 - accuracy: 0.9699 - val_loss: 0.6911 - val_accuracy: 0.8296
# Epoch 84/100
# 68/68 [==============================] - 31s 454ms/step - loss: 0.0818 - accuracy: 0.9713 - val_loss: 1.5012 - val_accuracy: 0.6889
# Epoch 85/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.0637 - accuracy: 0.9787 - val_loss: 0.6239 - val_accuracy: 0.8426
# Epoch 86/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.1112 - accuracy: 0.9630 - val_loss: 1.1563 - val_accuracy: 0.7667
# Epoch 87/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.0675 - accuracy: 0.9773 - val_loss: 0.6556 - val_accuracy: 0.8722
# Epoch 88/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.0765 - accuracy: 0.9755 - val_loss: 1.4745 - val_accuracy: 0.7315
# Epoch 89/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.0890 - accuracy: 0.9657 - val_loss: 0.8349 - val_accuracy: 0.7963
# Epoch 90/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.0879 - accuracy: 0.9694 - val_loss: 0.7016 - val_accuracy: 0.8574
# Epoch 91/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.1074 - accuracy: 0.9630 - val_loss: 1.2342 - val_accuracy: 0.7630
# Epoch 92/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.1252 - accuracy: 0.9634 - val_loss: 1.7790 - val_accuracy: 0.7185
# Epoch 93/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.0920 - accuracy: 0.9685 - val_loss: 1.2528 - val_accuracy: 0.7833
# Epoch 94/100
# 68/68 [==============================] - 31s 458ms/step - loss: 0.1441 - accuracy: 0.9463 - val_loss: 4.2785 - val_accuracy: 0.5870
# Epoch 95/100
# 68/68 [==============================] - 31s 457ms/step - loss: 0.1754 - accuracy: 0.9380 - val_loss: 1.6977 - val_accuracy: 0.7537
# Epoch 96/100
# 68/68 [==============================] - 31s 456ms/step - loss: 0.1098 - accuracy: 0.9579 - val_loss: 1.3913 - val_accuracy: 0.7241
# Epoch 97/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.0686 - accuracy: 0.9718 - val_loss: 1.7998 - val_accuracy: 0.6556
# Epoch 98/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.0530 - accuracy: 0.9796 - val_loss: 0.6633 - val_accuracy: 0.8574
# Epoch 99/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.0473 - accuracy: 0.9819 - val_loss: 1.1451 - val_accuracy: 0.7944
# Epoch 100/100
# 68/68 [==============================] - 31s 455ms/step - loss: 0.0732 - accuracy: 0.9759 - val_loss: 1.0667 - val_accuracy: 0.8111

# %%
metrics = hist.history
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(hist.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.title('Training and Validation Loss')
plt.subplot(1, 2, 2)
plt.plot(hist.epoch, metrics['accuracy'], metrics['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])
plt.title('Training and Validation Accuracy')
plt.show()

# %%
test_files = filenames = tf.io.gfile.glob(str(data_test) + '/*/*.jpg')
test_ds = pre_process(test_files)

# %%
test_images = []
test_labels = []

for image, label in test_ds:
  test_images.append(image.numpy())
  test_labels.append(label.numpy())

test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model.predict(test_images), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Test set accuracy: {test_acc:.0%}')
# Out:
# Test set accuracy: 77%

# %%
model.save('/content/drive/MyDrive/MobileNet_new.h5')

# %%
from tensorflow.contrib import lite
converter = lite.TFLiteConverter.from_keras_model_file( 'model.h5')
tfmodel = converter.convert()
open ("model.tflite" , "wb") .write(tfmodel)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=class_names,
            yticklabels=class_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()
