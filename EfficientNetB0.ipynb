# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import seaborn as sns
import random
import pathlib

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetB0

# %%
from google.colab import drive
drive._mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/dataset-original.zip" -d "/content/drive/MyDrive"

# %%
strategy = tf.distribute.MirroredStrategy()

print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of devices: 1

# %%
base_dir = '/content/drive/MyDrive/trash_dataset'
dataset = pathlib.Path(base_dir)
print(str(dataset))
# Out:
# /content/drive/MyDrive/trash_dataset

# %%
train_dir = str(dataset) + '/train'
test_dir = str(dataset) + '/test'
data_train = pathlib.Path(train_dir)
data_test = pathlib.Path(test_dir)

print(str(data_train))
print(str(data_test))
# Out:
# /content/drive/MyDrive/trash_dataset/train
# /content/drive/MyDrive/trash_dataset/test

# %%
class_names = np.array(tf.io.gfile.listdir(str(data_train)))
class_names = class_names[class_names != '.DS_Store']
print(class_names)
# Out:
# ['paper' 'metal' 'plastic' 'glass' 'trash' 'cardboard']

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2700 files belonging to 6 classes.
# Using 2160 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2700 files belonging to 6 classes.
# Using 540 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
def get_label(file_path):
  parts = tf.strings.split(file_path, os.path.sep)
  one_hot = parts[-2] == class_names
  return tf.argmax(one_hot)

# %%
def get_image(file_path):
  img = tf.io.read_file(file_path)
  img = tf.io.decode_jpeg(img, channels=3)
  img = tf.image.resize(img, [img_height, img_width])
  return img

# %%
def get_img_and_label(file_path):
  label = get_label(file_path)
  img = get_image(file_path)
  return img, label

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomRotation(factor=0.15),
    layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
    layers.RandomFlip(),
    layers.RandomContrast(factor=0.1)
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
def pre_process(image_files):
  files_ds = tf.data.Dataset.from_tensor_slices(image_files)
  image_ds = files_ds.map(map_func=get_img_and_label, num_parallel_calls=AUTOTUNE)
  return image_ds

# %%
num_classes = len(class_names)
print(num_classes)
# Out:
# 6

# %%
with strategy.scope():
  inputs = layers.Input(shape=(img_height, img_width, 3))
  x = data_augmentation(inputs)
  outputs = EfficientNetB0(include_top=True, weights=None, classes=num_classes)(x)
  model = tf.keras.Model(inputs, outputs)

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  efficientnetb0 (Functional)  (None, 6)                4057257
#
# =================================================================
# Total params: 4,057,257
# Trainable params: 4,015,234
# Non-trainable params: 42,023
# _________________________________________________________________

# %%
epochs = 100
hist = model.fit(train_ds, 
                 epochs=epochs, 
                 validation_data=val_ds)
# Out:
# Epoch 1/100
# 68/68 [==============================] - 76s 804ms/step - loss: 3.1785 - accuracy: 0.2602 - val_loss: 1.8716 - val_accuracy: 0.1519
# Epoch 2/100
# 68/68 [==============================] - 52s 760ms/step - loss: 2.1604 - accuracy: 0.3611 - val_loss: 1.9093 - val_accuracy: 0.1519
# Epoch 3/100
# 68/68 [==============================] - 52s 762ms/step - loss: 1.8809 - accuracy: 0.4273 - val_loss: 2.1878 - val_accuracy: 0.1519
# Epoch 4/100
# 68/68 [==============================] - 52s 761ms/step - loss: 1.6682 - accuracy: 0.4745 - val_loss: 1.8782 - val_accuracy: 0.1537
# Epoch 5/100
# 68/68 [==============================] - 52s 761ms/step - loss: 1.5224 - accuracy: 0.4986 - val_loss: 1.8640 - val_accuracy: 0.2185
# Epoch 6/100
# 68/68 [==============================] - 52s 761ms/step - loss: 1.4161 - accuracy: 0.5366 - val_loss: 2.0157 - val_accuracy: 0.2444
# Epoch 7/100
# 68/68 [==============================] - 52s 761ms/step - loss: 1.2893 - accuracy: 0.5657 - val_loss: 1.7627 - val_accuracy: 0.3185
# Epoch 8/100
# 68/68 [==============================] - 52s 761ms/step - loss: 1.2411 - accuracy: 0.5894 - val_loss: 1.2782 - val_accuracy: 0.5556
# Epoch 9/100
# 68/68 [==============================] - 52s 759ms/step - loss: 1.2025 - accuracy: 0.5782 - val_loss: 1.3678 - val_accuracy: 0.4833
# Epoch 10/100
# 68/68 [==============================] - 52s 761ms/step - loss: 1.1395 - accuracy: 0.6009 - val_loss: 1.3542 - val_accuracy: 0.5444
# Epoch 11/100
# 68/68 [==============================] - 52s 760ms/step - loss: 1.0932 - accuracy: 0.6153 - val_loss: 1.8890 - val_accuracy: 0.4370
# Epoch 12/100
# 68/68 [==============================] - 52s 761ms/step - loss: 1.2088 - accuracy: 0.6042 - val_loss: 1.3731 - val_accuracy: 0.5130
# Epoch 13/100
# 68/68 [==============================] - 52s 761ms/step - loss: 1.0839 - accuracy: 0.6264 - val_loss: 3.9087 - val_accuracy: 0.4926
# Epoch 14/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.9678 - accuracy: 0.6472 - val_loss: 1.7328 - val_accuracy: 0.5222
# Epoch 15/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.9305 - accuracy: 0.6699 - val_loss: 1.3188 - val_accuracy: 0.5278
# Epoch 16/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.8485 - accuracy: 0.6833 - val_loss: 1.6268 - val_accuracy: 0.5019
# Epoch 17/100
# 68/68 [==============================] - 52s 760ms/step - loss: 0.8119 - accuracy: 0.7074 - val_loss: 1.6754 - val_accuracy: 0.5093
# Epoch 18/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.9354 - accuracy: 0.6611 - val_loss: 2.2872 - val_accuracy: 0.4019
# Epoch 19/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.8040 - accuracy: 0.7199 - val_loss: 1.3105 - val_accuracy: 0.6000
# Epoch 20/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.7175 - accuracy: 0.7435 - val_loss: 2.5169 - val_accuracy: 0.3685
# Epoch 21/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.7090 - accuracy: 0.7481 - val_loss: 1.3319 - val_accuracy: 0.5852
# Epoch 22/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.6732 - accuracy: 0.7639 - val_loss: 2.5630 - val_accuracy: 0.3685
# Epoch 23/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.7296 - accuracy: 0.7505 - val_loss: 1.1675 - val_accuracy: 0.6019
# Epoch 24/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.6299 - accuracy: 0.7741 - val_loss: 1.0447 - val_accuracy: 0.6574
# Epoch 25/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.7069 - accuracy: 0.7398 - val_loss: 1.7844 - val_accuracy: 0.5241
# Epoch 26/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.6780 - accuracy: 0.7431 - val_loss: 2.8988 - val_accuracy: 0.3407
# Epoch 27/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.5823 - accuracy: 0.7949 - val_loss: 0.9916 - val_accuracy: 0.6759
# Epoch 28/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.5240 - accuracy: 0.8079 - val_loss: 1.3140 - val_accuracy: 0.6019
# Epoch 29/100
# 68/68 [==============================] - 52s 760ms/step - loss: 0.5174 - accuracy: 0.8176 - val_loss: 1.1872 - val_accuracy: 0.6389
# Epoch 30/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.4969 - accuracy: 0.8116 - val_loss: 1.5731 - val_accuracy: 0.5648
# Epoch 31/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.4969 - accuracy: 0.8222 - val_loss: 0.6994 - val_accuracy: 0.7944
# Epoch 32/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.4786 - accuracy: 0.8343 - val_loss: 1.2827 - val_accuracy: 0.6667
# Epoch 33/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.5126 - accuracy: 0.8181 - val_loss: 2.6362 - val_accuracy: 0.4333
# Epoch 34/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.5515 - accuracy: 0.8042 - val_loss: 0.9238 - val_accuracy: 0.7167
# Epoch 35/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.4436 - accuracy: 0.8449 - val_loss: 1.5410 - val_accuracy: 0.5667
# Epoch 36/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.4366 - accuracy: 0.8449 - val_loss: 1.4056 - val_accuracy: 0.6093
# Epoch 37/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.4146 - accuracy: 0.8528 - val_loss: 0.9916 - val_accuracy: 0.7019
# Epoch 38/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.4008 - accuracy: 0.8593 - val_loss: 1.1016 - val_accuracy: 0.7000
# Epoch 39/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.3819 - accuracy: 0.8671 - val_loss: 1.1880 - val_accuracy: 0.7019
# Epoch 40/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.3747 - accuracy: 0.8602 - val_loss: 1.8392 - val_accuracy: 0.5833
# Epoch 41/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.3745 - accuracy: 0.8778 - val_loss: 1.0804 - val_accuracy: 0.6833
# Epoch 42/100
# 68/68 [==============================] - 52s 760ms/step - loss: 0.3814 - accuracy: 0.8667 - val_loss: 0.6074 - val_accuracy: 0.8167
# Epoch 43/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.3477 - accuracy: 0.8829 - val_loss: 2.4182 - val_accuracy: 0.4648
# Epoch 44/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.4957 - accuracy: 0.8380 - val_loss: 1.5199 - val_accuracy: 0.5889
# Epoch 45/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.3911 - accuracy: 0.8620 - val_loss: 1.1366 - val_accuracy: 0.6926
# Epoch 46/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.3290 - accuracy: 0.8810 - val_loss: 0.6009 - val_accuracy: 0.8278
# Epoch 47/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.3195 - accuracy: 0.8907 - val_loss: 1.2739 - val_accuracy: 0.6833
# Epoch 48/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.2757 - accuracy: 0.9051 - val_loss: 0.9437 - val_accuracy: 0.7296
# Epoch 49/100
# 68/68 [==============================] - 52s 760ms/step - loss: 0.2534 - accuracy: 0.9083 - val_loss: 2.0549 - val_accuracy: 0.5407
# Epoch 50/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.4232 - accuracy: 0.8565 - val_loss: 1.9063 - val_accuracy: 0.5907
# Epoch 51/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.2772 - accuracy: 0.9051 - val_loss: 4.0188 - val_accuracy: 0.3722
# Epoch 52/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.2542 - accuracy: 0.9060 - val_loss: 1.0031 - val_accuracy: 0.7630
# Epoch 53/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.2221 - accuracy: 0.9236 - val_loss: 0.8948 - val_accuracy: 0.7667
# Epoch 54/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.2460 - accuracy: 0.9167 - val_loss: 0.8228 - val_accuracy: 0.8130
# Epoch 55/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.2417 - accuracy: 0.9231 - val_loss: 1.4382 - val_accuracy: 0.6741
# Epoch 56/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.2245 - accuracy: 0.9190 - val_loss: 0.8759 - val_accuracy: 0.7815
# Epoch 57/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.1816 - accuracy: 0.9403 - val_loss: 0.7266 - val_accuracy: 0.8093
# Epoch 58/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.1927 - accuracy: 0.9329 - val_loss: 1.4237 - val_accuracy: 0.7370
# Epoch 59/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.1946 - accuracy: 0.9292 - val_loss: 1.5179 - val_accuracy: 0.6593
# Epoch 60/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.1898 - accuracy: 0.9324 - val_loss: 1.3597 - val_accuracy: 0.6685
# Epoch 61/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.1845 - accuracy: 0.9356 - val_loss: 0.7031 - val_accuracy: 0.8167
# Epoch 62/100
# 68/68 [==============================] - 52s 764ms/step - loss: 0.1732 - accuracy: 0.9458 - val_loss: 2.2460 - val_accuracy: 0.6130
# Epoch 63/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.1691 - accuracy: 0.9477 - val_loss: 1.4861 - val_accuracy: 0.6407
# Epoch 64/100
# 68/68 [==============================] - 52s 765ms/step - loss: 0.1798 - accuracy: 0.9319 - val_loss: 2.9603 - val_accuracy: 0.4889
# Epoch 65/100
# 68/68 [==============================] - 52s 764ms/step - loss: 0.1730 - accuracy: 0.9380 - val_loss: 1.4789 - val_accuracy: 0.6593
# Epoch 66/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.1788 - accuracy: 0.9361 - val_loss: 1.2917 - val_accuracy: 0.7056
# Epoch 67/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.1584 - accuracy: 0.9444 - val_loss: 1.8261 - val_accuracy: 0.6352
# Epoch 68/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.1746 - accuracy: 0.9417 - val_loss: 0.9162 - val_accuracy: 0.7444
# Epoch 69/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.1628 - accuracy: 0.9435 - val_loss: 1.1861 - val_accuracy: 0.7370
# Epoch 70/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.1411 - accuracy: 0.9523 - val_loss: 1.0458 - val_accuracy: 0.7685
# Epoch 71/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.1729 - accuracy: 0.9407 - val_loss: 1.0851 - val_accuracy: 0.7259
# Epoch 72/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.1749 - accuracy: 0.9370 - val_loss: 1.1582 - val_accuracy: 0.7519
# Epoch 73/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.1577 - accuracy: 0.9444 - val_loss: 1.9188 - val_accuracy: 0.5426
# Epoch 74/100
# 68/68 [==============================] - 52s 764ms/step - loss: 0.1347 - accuracy: 0.9523 - val_loss: 2.3578 - val_accuracy: 0.5500
# Epoch 75/100
# 68/68 [==============================] - 52s 761ms/step - loss: 0.1566 - accuracy: 0.9463 - val_loss: 1.2115 - val_accuracy: 0.7241
# Epoch 76/100
# 68/68 [==============================] - 52s 764ms/step - loss: 0.1595 - accuracy: 0.9431 - val_loss: 3.9325 - val_accuracy: 0.4056
# Epoch 77/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.0958 - accuracy: 0.9671 - val_loss: 0.9385 - val_accuracy: 0.8093
# Epoch 78/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.1319 - accuracy: 0.9546 - val_loss: 0.7723 - val_accuracy: 0.8093
# Epoch 79/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.1144 - accuracy: 0.9634 - val_loss: 1.0770 - val_accuracy: 0.7852
# Epoch 80/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.0915 - accuracy: 0.9662 - val_loss: 2.0158 - val_accuracy: 0.6648
# Epoch 81/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.1620 - accuracy: 0.9431 - val_loss: 2.4092 - val_accuracy: 0.5722
# Epoch 82/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.1323 - accuracy: 0.9569 - val_loss: 0.9615 - val_accuracy: 0.8000
# Epoch 83/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.0706 - accuracy: 0.9773 - val_loss: 1.3103 - val_accuracy: 0.7685
# Epoch 84/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.1126 - accuracy: 0.9597 - val_loss: 0.9939 - val_accuracy: 0.7722
# Epoch 85/100
# 68/68 [==============================] - 52s 766ms/step - loss: 0.0971 - accuracy: 0.9657 - val_loss: 2.1825 - val_accuracy: 0.6037
# Epoch 86/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.1125 - accuracy: 0.9597 - val_loss: 1.2272 - val_accuracy: 0.7148
# Epoch 87/100
# 68/68 [==============================] - 52s 765ms/step - loss: 0.0757 - accuracy: 0.9773 - val_loss: 0.9447 - val_accuracy: 0.8056
# Epoch 88/100
# 68/68 [==============================] - 52s 765ms/step - loss: 0.1219 - accuracy: 0.9616 - val_loss: 6.0497 - val_accuracy: 0.4130
# Epoch 89/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.1027 - accuracy: 0.9639 - val_loss: 1.2598 - val_accuracy: 0.7407
# Epoch 90/100
# 68/68 [==============================] - 52s 764ms/step - loss: 0.1006 - accuracy: 0.9648 - val_loss: 2.2598 - val_accuracy: 0.5852
# Epoch 91/100
# 68/68 [==============================] - 52s 766ms/step - loss: 0.1186 - accuracy: 0.9602 - val_loss: 4.0644 - val_accuracy: 0.4241
# Epoch 92/100
# 68/68 [==============================] - 52s 765ms/step - loss: 0.4101 - accuracy: 0.8773 - val_loss: 4.6906 - val_accuracy: 0.2870
# Epoch 93/100
# 68/68 [==============================] - 52s 765ms/step - loss: 0.2433 - accuracy: 0.9185 - val_loss: 1.3114 - val_accuracy: 0.6667
# Epoch 94/100
# 68/68 [==============================] - 52s 764ms/step - loss: 0.1514 - accuracy: 0.9458 - val_loss: 2.4770 - val_accuracy: 0.5556
# Epoch 95/100
# 68/68 [==============================] - 52s 764ms/step - loss: 0.1054 - accuracy: 0.9625 - val_loss: 1.2023 - val_accuracy: 0.7500
# Epoch 96/100
# 68/68 [==============================] - 52s 765ms/step - loss: 0.1372 - accuracy: 0.9556 - val_loss: 0.7500 - val_accuracy: 0.8204
# Epoch 97/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.1071 - accuracy: 0.9602 - val_loss: 0.7769 - val_accuracy: 0.8019
# Epoch 98/100
# 68/68 [==============================] - 52s 764ms/step - loss: 0.1225 - accuracy: 0.9519 - val_loss: 0.6700 - val_accuracy: 0.8537
# Epoch 99/100
# 68/68 [==============================] - 52s 762ms/step - loss: 0.0848 - accuracy: 0.9676 - val_loss: 1.1754 - val_accuracy: 0.7463
# Epoch 100/100
# 68/68 [==============================] - 52s 763ms/step - loss: 0.1009 - accuracy: 0.9667 - val_loss: 0.9692 - val_accuracy: 0.8000

# %%
metrics = hist.history
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(hist.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.title('Training and Validation Loss')
plt.subplot(1, 2, 2)
plt.plot(hist.epoch, metrics['accuracy'], metrics['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])
plt.title('Training and Validation Accuracy')
plt.show()

# %%
test_files = filenames = tf.io.gfile.glob(str(data_test) + '/*/*.jpg')
test_ds = pre_process(test_files)

# %%
test_images = []
test_labels = []

for image, label in test_ds:
  test_images.append(image.numpy())
  test_labels.append(label.numpy())

test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
model_EffB0 = tf.keras.models.load_model('/content/drive/MyDrive/EfficientNet_new.h5')

# %%
loss, acc = model_EffB0.evaluate(test_images, test_labels)
print('Restored model, accuracy: {:5.0f}%'.format(100 * acc))
# Out:
# 20/20 [==============================] - 5s 152ms/step - loss: 1.4031 - accuracy: 0.6984
# Restored model, accuracy:    70%

# %%
from sklearn.metrics import classification_report

y_pred = np.argmax(model_EffB0.predict(test_images), axis=1)
y_true = test_labels

print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#    cardboard       0.83      0.79      0.81       101
#        glass       0.62      0.74      0.68       125
#        metal       0.53      0.82      0.64       102
#        paper       0.92      0.71      0.80       148
#      plastic       0.80      0.47      0.59       120
#        trash       0.52      0.65      0.58        34
#
#     accuracy                           0.70       630
#    macro avg       0.71      0.70      0.68       630
# weighted avg       0.74      0.70      0.70       630

# %%
import sklearn.metrics as skm

cm = skm.multilabel_confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# [[[513  16]
#   [ 21  80]]
#
#  [[449  56]
#   [ 32  93]]
#
#  [[453  75]
#   [ 18  84]]
#
#  [[473   9]
#   [ 43 105]]
#
#  [[496  14]
#   [ 64  56]]
#
#  [[576  20]
#   [ 12  22]]]

# %%
y_pred = np.argmax(model.predict(test_images), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Test set accuracy: {test_acc:.0%}')
# Out:
# Test set accuracy: 70%

# %%
model.save('/content/drive/MyDrive/EfficientNet_new.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
from tensorflow.contrib import lite
converter = lite.TFLiteConverter.from_keras_model_file( 'model.h5')
tfmodel = converter.convert()
open ("model.tflite" , "wb") .write(tfmodel)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=class_names,
            yticklabels=class_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()
