# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import seaborn as sns
import random
import pathlib

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.applications import InceptionV3

# %%
from google.colab import drive
drive._mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/dataset-original.zip" -d "/content/drive/MyDrive"

# %%
strategy = tf.distribute.MirroredStrategy()

print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of devices: 1

# %%
base_dir = '/content/drive/MyDrive/trash_dataset'
dataset = pathlib.Path(base_dir)
print(str(dataset))
# Out:
# /content/drive/MyDrive/trash_dataset

# %%
train_dir = str(dataset) + '/train'
test_dir = str(dataset) + '/test'
data_train = pathlib.Path(train_dir)
data_test = pathlib.Path(test_dir)

print(str(data_train))
print(str(data_test))
# Out:
# /content/drive/MyDrive/trash_dataset/train
# /content/drive/MyDrive/trash_dataset/test

# %%
class_names = np.array(tf.io.gfile.listdir(str(data_train)))
class_names = class_names[class_names != '.DS_Store']
print(class_names)
# Out:
# ['paper' 'metal' 'plastic' 'glass' 'trash' 'cardboard']

# %%
batch_size = 32
img_height = 299
img_width = 299

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2700 files belonging to 6 classes.
# Using 2160 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2700 files belonging to 6 classes.
# Using 540 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
def get_label(file_path):
  parts = tf.strings.split(file_path, os.path.sep)
  one_hot = parts[-2] == class_names
  return tf.argmax(one_hot)

# %%
def get_image(file_path):
  img = tf.io.read_file(file_path)
  img = tf.io.decode_jpeg(img, channels=3)
  img = tf.image.resize(img, [img_height, img_width])
  return img

# %%
def get_img_and_label(file_path):
  label = get_label(file_path)
  img = get_image(file_path)
  return img, label

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomRotation(factor=0.15),
    layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
    layers.RandomFlip(),
    layers.RandomContrast(factor=0.1)
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
def pre_process(image_files):
  files_ds = tf.data.Dataset.from_tensor_slices(image_files)
  image_ds = files_ds.map(map_func=get_img_and_label, num_parallel_calls=AUTOTUNE)
  return image_ds

# %%
num_classes = len(class_names)
print(num_classes)
# Out:
# 6

# %%
from tensorflow.keras.optimizers import Adam

with strategy.scope():
  inputs = layers.Input(shape=(img_height, img_width, 3))
  x = data_augmentation(inputs)
  x = tf.keras.applications.inception_v3.preprocess_input(x, data_format=None)
  outputs = InceptionV3(include_top=True, weights=None, classes=num_classes)(x)
  model = tf.keras.Model(inputs, outputs)

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  sequential (Sequential)     (None, 299, 299, 3)       0
#
#  tf.math.truediv (TFOpLambda  (None, 299, 299, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 299, 299, 3)      0
#  a)
#
#  inception_v3 (Functional)   (None, 6)                 21815078
#
# =================================================================
# Total params: 21,815,078
# Trainable params: 21,780,646
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
epochs = 100
hist = model.fit(train_ds, 
                 epochs=epochs, 
                 validation_data=val_ds)
# Out:
# Epoch 1/100
# 68/68 [==============================] - 1148s 4s/step - loss: 1.5887 - accuracy: 0.4282 - val_loss: 6.1686 - val_accuracy: 0.1519
# Epoch 2/100
# 68/68 [==============================] - 74s 1s/step - loss: 1.3209 - accuracy: 0.4958 - val_loss: 2.2070 - val_accuracy: 0.2241
# Epoch 3/100
# 68/68 [==============================] - 74s 1s/step - loss: 1.2547 - accuracy: 0.5444 - val_loss: 2.8452 - val_accuracy: 0.2093
# Epoch 4/100
# 68/68 [==============================] - 74s 1s/step - loss: 1.2528 - accuracy: 0.5481 - val_loss: 14.4009 - val_accuracy: 0.2519
# Epoch 5/100
# 68/68 [==============================] - 74s 1s/step - loss: 1.1318 - accuracy: 0.5921 - val_loss: 5.3567 - val_accuracy: 0.4259
# Epoch 6/100
# 68/68 [==============================] - 73s 1s/step - loss: 1.1161 - accuracy: 0.5829 - val_loss: 12.6432 - val_accuracy: 0.3370
# Epoch 7/100
# 68/68 [==============================] - 73s 1s/step - loss: 1.0664 - accuracy: 0.6088 - val_loss: 1.5672 - val_accuracy: 0.5278
# Epoch 8/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.9986 - accuracy: 0.6384 - val_loss: 1.7374 - val_accuracy: 0.6167
# Epoch 9/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.9599 - accuracy: 0.6560 - val_loss: 2.0229 - val_accuracy: 0.5463
# Epoch 10/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.9032 - accuracy: 0.6731 - val_loss: 1.2486 - val_accuracy: 0.6333
# Epoch 11/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.8580 - accuracy: 0.6949 - val_loss: 1.1808 - val_accuracy: 0.6185
# Epoch 12/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.8646 - accuracy: 0.6856 - val_loss: 1.7852 - val_accuracy: 0.4593
# Epoch 13/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.8460 - accuracy: 0.6898 - val_loss: 3.7665 - val_accuracy: 0.4667
# Epoch 14/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.8303 - accuracy: 0.6870 - val_loss: 0.9311 - val_accuracy: 0.6963
# Epoch 15/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.7854 - accuracy: 0.7213 - val_loss: 2.1847 - val_accuracy: 0.4722
# Epoch 16/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.7265 - accuracy: 0.7431 - val_loss: 0.8755 - val_accuracy: 0.7093
# Epoch 17/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.7358 - accuracy: 0.7361 - val_loss: 1.1391 - val_accuracy: 0.6481
# Epoch 18/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.7284 - accuracy: 0.7431 - val_loss: 0.9571 - val_accuracy: 0.7130
# Epoch 19/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.6492 - accuracy: 0.7630 - val_loss: 1.0431 - val_accuracy: 0.6463
# Epoch 20/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.5801 - accuracy: 0.7852 - val_loss: 1.1527 - val_accuracy: 0.6463
# Epoch 21/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.5955 - accuracy: 0.7856 - val_loss: 1.9930 - val_accuracy: 0.5389
# Epoch 22/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.5636 - accuracy: 0.7995 - val_loss: 1.5248 - val_accuracy: 0.6111
# Epoch 23/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.5801 - accuracy: 0.7963 - val_loss: 0.9485 - val_accuracy: 0.6778
# Epoch 24/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.5343 - accuracy: 0.8116 - val_loss: 1.1501 - val_accuracy: 0.6667
# Epoch 25/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.5226 - accuracy: 0.8000 - val_loss: 1.0560 - val_accuracy: 0.6907
# Epoch 26/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.5251 - accuracy: 0.8093 - val_loss: 1.1159 - val_accuracy: 0.7074
# Epoch 27/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.4810 - accuracy: 0.8269 - val_loss: 0.7773 - val_accuracy: 0.7500
# Epoch 28/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.4870 - accuracy: 0.8264 - val_loss: 1.1322 - val_accuracy: 0.6796
# Epoch 29/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.4463 - accuracy: 0.8449 - val_loss: 0.6721 - val_accuracy: 0.8000
# Epoch 30/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.4322 - accuracy: 0.8495 - val_loss: 1.8514 - val_accuracy: 0.5056
# Epoch 31/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.4440 - accuracy: 0.8491 - val_loss: 1.3749 - val_accuracy: 0.6444
# Epoch 32/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.4285 - accuracy: 0.8426 - val_loss: 1.3569 - val_accuracy: 0.7222
# Epoch 33/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.3955 - accuracy: 0.8514 - val_loss: 0.8301 - val_accuracy: 0.7722
# Epoch 34/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.3866 - accuracy: 0.8593 - val_loss: 1.1360 - val_accuracy: 0.6907
# Epoch 35/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.4093 - accuracy: 0.8569 - val_loss: 0.7723 - val_accuracy: 0.7704
# Epoch 36/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.3579 - accuracy: 0.8745 - val_loss: 1.3426 - val_accuracy: 0.7444
# Epoch 37/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.3121 - accuracy: 0.8935 - val_loss: 0.9114 - val_accuracy: 0.7407
# Epoch 38/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.3578 - accuracy: 0.8704 - val_loss: 1.1653 - val_accuracy: 0.6926
# Epoch 39/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.3401 - accuracy: 0.8759 - val_loss: 1.5956 - val_accuracy: 0.6796
# Epoch 40/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.3209 - accuracy: 0.8829 - val_loss: 0.5899 - val_accuracy: 0.8037
# Epoch 41/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.3131 - accuracy: 0.8889 - val_loss: 1.2037 - val_accuracy: 0.6574
# Epoch 42/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.3341 - accuracy: 0.8782 - val_loss: 1.9741 - val_accuracy: 0.6407
# Epoch 43/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.2771 - accuracy: 0.8991 - val_loss: 0.7894 - val_accuracy: 0.7556
# Epoch 44/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.2708 - accuracy: 0.8995 - val_loss: 1.1038 - val_accuracy: 0.7278
# Epoch 45/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.2748 - accuracy: 0.9014 - val_loss: 1.3297 - val_accuracy: 0.6574
# Epoch 46/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.2318 - accuracy: 0.9199 - val_loss: 1.0168 - val_accuracy: 0.7556
# Epoch 47/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.2742 - accuracy: 0.9023 - val_loss: 0.7050 - val_accuracy: 0.7981
# Epoch 48/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.2311 - accuracy: 0.9157 - val_loss: 0.8975 - val_accuracy: 0.7426
# Epoch 49/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.2665 - accuracy: 0.9051 - val_loss: 0.8655 - val_accuracy: 0.7944
# Epoch 50/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.2469 - accuracy: 0.9120 - val_loss: 0.6517 - val_accuracy: 0.8111
# Epoch 51/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.2108 - accuracy: 0.9282 - val_loss: 0.6825 - val_accuracy: 0.8037
# Epoch 52/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.2096 - accuracy: 0.9194 - val_loss: 1.6538 - val_accuracy: 0.6778
# Epoch 53/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.2113 - accuracy: 0.9236 - val_loss: 0.6336 - val_accuracy: 0.8444
# Epoch 54/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.2052 - accuracy: 0.9227 - val_loss: 1.2032 - val_accuracy: 0.7111
# Epoch 55/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.2335 - accuracy: 0.9134 - val_loss: 1.1405 - val_accuracy: 0.7241
# Epoch 56/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1863 - accuracy: 0.9310 - val_loss: 0.6365 - val_accuracy: 0.8204
# Epoch 57/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.2148 - accuracy: 0.9236 - val_loss: 1.3813 - val_accuracy: 0.6593
# Epoch 58/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.1933 - accuracy: 0.9310 - val_loss: 1.3923 - val_accuracy: 0.7259
# Epoch 59/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.1508 - accuracy: 0.9440 - val_loss: 0.6112 - val_accuracy: 0.8111
# Epoch 60/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.1335 - accuracy: 0.9579 - val_loss: 1.4209 - val_accuracy: 0.7000
# Epoch 61/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1522 - accuracy: 0.9458 - val_loss: 0.6986 - val_accuracy: 0.8241
# Epoch 62/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.1416 - accuracy: 0.9523 - val_loss: 0.7441 - val_accuracy: 0.8222
# Epoch 63/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1681 - accuracy: 0.9366 - val_loss: 1.3220 - val_accuracy: 0.6889
# Epoch 64/100
# 68/68 [==============================] - 75s 1s/step - loss: 0.2090 - accuracy: 0.9306 - val_loss: 0.8032 - val_accuracy: 0.7796
# Epoch 65/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1494 - accuracy: 0.9407 - val_loss: 1.9504 - val_accuracy: 0.7056
# Epoch 66/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1325 - accuracy: 0.9551 - val_loss: 0.5555 - val_accuracy: 0.8333
# Epoch 67/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1189 - accuracy: 0.9546 - val_loss: 0.6765 - val_accuracy: 0.8167
# Epoch 68/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1263 - accuracy: 0.9472 - val_loss: 0.7452 - val_accuracy: 0.7907
# Epoch 69/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1853 - accuracy: 0.9361 - val_loss: 2.1610 - val_accuracy: 0.6426
# Epoch 70/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1533 - accuracy: 0.9481 - val_loss: 0.7861 - val_accuracy: 0.8296
# Epoch 71/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0922 - accuracy: 0.9690 - val_loss: 1.2239 - val_accuracy: 0.7611
# Epoch 72/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0767 - accuracy: 0.9708 - val_loss: 1.0521 - val_accuracy: 0.7630
# Epoch 73/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1241 - accuracy: 0.9560 - val_loss: 0.8950 - val_accuracy: 0.8130
# Epoch 74/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.2038 - accuracy: 0.9287 - val_loss: 1.3089 - val_accuracy: 0.7611
# Epoch 75/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1665 - accuracy: 0.9417 - val_loss: 0.6409 - val_accuracy: 0.8296
# Epoch 76/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1250 - accuracy: 0.9519 - val_loss: 0.9812 - val_accuracy: 0.7796
# Epoch 77/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.1154 - accuracy: 0.9537 - val_loss: 1.2817 - val_accuracy: 0.7296
# Epoch 78/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1244 - accuracy: 0.9565 - val_loss: 0.5731 - val_accuracy: 0.8574
# Epoch 79/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0988 - accuracy: 0.9616 - val_loss: 1.2012 - val_accuracy: 0.7796
# Epoch 80/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0705 - accuracy: 0.9769 - val_loss: 0.8155 - val_accuracy: 0.8278
# Epoch 81/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0763 - accuracy: 0.9731 - val_loss: 0.6299 - val_accuracy: 0.8593
# Epoch 82/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.0876 - accuracy: 0.9639 - val_loss: 0.7041 - val_accuracy: 0.8185
# Epoch 83/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0924 - accuracy: 0.9727 - val_loss: 0.7747 - val_accuracy: 0.8296
# Epoch 84/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1264 - accuracy: 0.9542 - val_loss: 0.7652 - val_accuracy: 0.8426
# Epoch 85/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1315 - accuracy: 0.9519 - val_loss: 1.1836 - val_accuracy: 0.8093
# Epoch 86/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.1768 - accuracy: 0.9449 - val_loss: 5.1580 - val_accuracy: 0.5315
# Epoch 87/100
# 68/68 [==============================] - 73s 1s/step - loss: 0.1679 - accuracy: 0.9417 - val_loss: 0.8411 - val_accuracy: 0.7704
# Epoch 88/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1501 - accuracy: 0.9486 - val_loss: 0.8801 - val_accuracy: 0.8111
# Epoch 89/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0770 - accuracy: 0.9750 - val_loss: 0.4991 - val_accuracy: 0.8593
# Epoch 90/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0759 - accuracy: 0.9727 - val_loss: 0.8700 - val_accuracy: 0.8037
# Epoch 91/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1252 - accuracy: 0.9588 - val_loss: 0.6599 - val_accuracy: 0.8315
# Epoch 92/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0696 - accuracy: 0.9787 - val_loss: 0.4904 - val_accuracy: 0.8574
# Epoch 93/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0463 - accuracy: 0.9861 - val_loss: 0.5598 - val_accuracy: 0.8685
# Epoch 94/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0631 - accuracy: 0.9824 - val_loss: 1.3542 - val_accuracy: 0.7778
# Epoch 95/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1233 - accuracy: 0.9606 - val_loss: 1.3461 - val_accuracy: 0.7593
# Epoch 96/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0959 - accuracy: 0.9667 - val_loss: 1.0829 - val_accuracy: 0.7907
# Epoch 97/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1268 - accuracy: 0.9565 - val_loss: 1.7947 - val_accuracy: 0.6685
# Epoch 98/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.1512 - accuracy: 0.9583 - val_loss: 0.8860 - val_accuracy: 0.8259
# Epoch 99/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0870 - accuracy: 0.9727 - val_loss: 0.7111 - val_accuracy: 0.8259
# Epoch 100/100
# 68/68 [==============================] - 74s 1s/step - loss: 0.0938 - accuracy: 0.9736 - val_loss: 0.7374 - val_accuracy: 0.8056

# %%
metrics = hist.history
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(hist.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.title('Training and Validation Loss')
plt.subplot(1, 2, 2)
plt.plot(hist.epoch, metrics['accuracy'], metrics['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])
plt.title('Training and Validation Accuracy')
plt.show()

# %%
test_files = filenames = tf.io.gfile.glob(str(data_test) + '/*/*.jpg')
test_ds = pre_process(test_files)

# %%
test_images = []
test_labels = []

for image, label in test_ds:
  test_images.append(image.numpy())
  test_labels.append(label.numpy())

test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
model_IncepV3 = tf.keras.models.load_model('/content/drive/MyDrive/InceptionV3_new.h5')

# %%
loss, acc = model_IncepV3.evaluate(test_images, test_labels)
print('Restored model, accuracy: {:5.0f}%'.format(100 * acc))
# Out:
# 20/20 [==============================] - 8s 299ms/step - loss: 1.1544 - accuracy: 0.7730
# Restored model, accuracy:    77%

# %%
from sklearn.metrics import classification_report

y_pred = np.argmax(model_IncepV3.predict(test_images), axis=1)
y_true = test_labels

print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#    cardboard       0.87      0.81      0.84       101
#        glass       0.86      0.70      0.77       125
#        metal       0.68      0.76      0.72       102
#        paper       0.79      0.87      0.83       148
#      plastic       0.81      0.72      0.76       120
#        trash       0.49      0.71      0.58        34
#
#     accuracy                           0.77       630
#    macro avg       0.75      0.76      0.75       630
# weighted avg       0.79      0.77      0.78       630

# %%
import sklearn.metrics as skm

cm = skm.multilabel_confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# [[[517  12]
#   [ 19  82]]
#
#  [[491  14]
#   [ 38  87]]
#
#  [[492  36]
#   [ 24  78]]
#
#  [[447  35]
#   [ 19 129]]
#
#  [[489  21]
#   [ 33  87]]
#
#  [[571  25]
#   [ 10  24]]]

# %%
y_pred = np.argmax(model.predict(test_images), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Test set accuracy: {test_acc:.0%}')
# Out:
# Test set accuracy: 77%

# %%
model.save('/content/drive/MyDrive/InceptionV3_new.h5')

# %%
from tensorflow.contrib import lite
converter = lite.TFLiteConverter.from_keras_model_file( 'model.h5')
tfmodel = converter.convert()
open ("model.tflite" , "wb") .write(tfmodel)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=class_names,
            yticklabels=class_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()
