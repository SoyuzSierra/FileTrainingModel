# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import seaborn as sns
import random
import pathlib

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetB2

# %%
# !unzip "/content/drive/MyDrive/dataset-original.zip" -d "/content/drive/MyDrive"

# %%
strategy = tf.distribute.MirroredStrategy()

print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of devices: 1

# %%
base_dir = '/content/drive/MyDrive/trash_dataset'
dataset = pathlib.Path(base_dir)
print(str(dataset))
# Out:
# /content/drive/MyDrive/trash_dataset

# %%
train_dir = str(dataset) + '/train'
test_dir = str(dataset) + '/test'
data_train = pathlib.Path(train_dir)
data_test = pathlib.Path(test_dir)

print(str(data_train))
print(str(data_test))
# Out:
# /content/drive/MyDrive/trash_dataset/train
# /content/drive/MyDrive/trash_dataset/test

# %%
class_names = np.array(tf.io.gfile.listdir(str(data_train)))
class_names = class_names[class_names != '.DS_Store']
print(class_names)
# Out:
# ['paper' 'metal' 'plastic' 'glass' 'trash' 'cardboard']

# %%
batch_size = 32
img_height = 260
img_width = 260

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2700 files belonging to 6 classes.
# Using 2160 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2700 files belonging to 6 classes.
# Using 540 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
def get_label(file_path):
  parts = tf.strings.split(file_path, os.path.sep)
  one_hot = parts[-2] == class_names
  return tf.argmax(one_hot)

# %%
def get_image(file_path):
  img = tf.io.read_file(file_path)
  img = tf.io.decode_jpeg(img, channels=3)
  img = tf.image.resize(img, [img_height, img_width])
  return img

# %%
def get_img_and_label(file_path):
  label = get_label(file_path)
  img = get_image(file_path)
  return img, label

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomRotation(factor=0.15),
    layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
    layers.RandomFlip(),
    layers.RandomContrast(factor=0.1)
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
def pre_process(image_files):
  files_ds = tf.data.Dataset.from_tensor_slices(image_files)
  image_ds = files_ds.map(map_func=get_img_and_label, num_parallel_calls=AUTOTUNE)
  return image_ds

# %%
num_classes = len(class_names)
print(num_classes)
# Out:
# 6

# %%
with strategy.scope():
  inputs = layers.Input(shape=(img_height, img_width, 3))
  x = data_augmentation(inputs)
  outputs = EfficientNetB2(include_top=True, weights=None, classes=num_classes)(x)
  model = tf.keras.Model(inputs, outputs)

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 260, 260, 3)]     0
#
#  sequential (Sequential)     (None, None, None, 3)     0
#
#  efficientnetb2 (Functional)  (None, 6)                7777023
#
# =================================================================
# Total params: 7,777,023
# Trainable params: 7,709,448
# Non-trainable params: 67,575
# _________________________________________________________________

# %%
epochs = 100
hist = model.fit(train_ds, 
                 epochs=epochs, 
                 validation_data=val_ds)
# Out:
# Epoch 1/100
# 68/68 [==============================] - 954s 4s/step - loss: 2.9267 - accuracy: 0.2032 - val_loss: 1.9573 - val_accuracy: 0.1667
# Epoch 2/100
# 68/68 [==============================] - 93s 1s/step - loss: 2.2705 - accuracy: 0.2329 - val_loss: 1.8800 - val_accuracy: 0.1519
# Epoch 3/100
# 68/68 [==============================] - 93s 1s/step - loss: 2.0584 - accuracy: 0.3032 - val_loss: 1.8966 - val_accuracy: 0.1667
# Epoch 4/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.7123 - accuracy: 0.3685 - val_loss: 1.8307 - val_accuracy: 0.1963
# Epoch 5/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.5855 - accuracy: 0.4208 - val_loss: 1.7898 - val_accuracy: 0.2222
# Epoch 6/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.5427 - accuracy: 0.4421 - val_loss: 1.6676 - val_accuracy: 0.3241
# Epoch 7/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.4820 - accuracy: 0.4815 - val_loss: 1.7257 - val_accuracy: 0.3222
# Epoch 8/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.4180 - accuracy: 0.4977 - val_loss: 1.7729 - val_accuracy: 0.3685
# Epoch 9/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.4178 - accuracy: 0.5042 - val_loss: 2.8606 - val_accuracy: 0.3500
# Epoch 10/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.3324 - accuracy: 0.5333 - val_loss: 1.9757 - val_accuracy: 0.4389
# Epoch 11/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.2714 - accuracy: 0.5556 - val_loss: 2.0876 - val_accuracy: 0.2611
# Epoch 12/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.1969 - accuracy: 0.5759 - val_loss: 1.2028 - val_accuracy: 0.5556
# Epoch 13/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.0994 - accuracy: 0.6088 - val_loss: 2.2139 - val_accuracy: 0.3648
# Epoch 14/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.1403 - accuracy: 0.5921 - val_loss: 1.7440 - val_accuracy: 0.4722
# Epoch 15/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.0501 - accuracy: 0.6236 - val_loss: 2.0350 - val_accuracy: 0.3630
# Epoch 16/100
# 68/68 [==============================] - 93s 1s/step - loss: 1.0000 - accuracy: 0.6352 - val_loss: 1.4422 - val_accuracy: 0.5056
# Epoch 17/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.9762 - accuracy: 0.6574 - val_loss: 0.9919 - val_accuracy: 0.6444
# Epoch 18/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.9587 - accuracy: 0.6634 - val_loss: 1.1673 - val_accuracy: 0.6037
# Epoch 19/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.9166 - accuracy: 0.6819 - val_loss: 1.3443 - val_accuracy: 0.5815
# Epoch 20/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.8417 - accuracy: 0.6903 - val_loss: 2.0302 - val_accuracy: 0.4185
# Epoch 21/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.9411 - accuracy: 0.6606 - val_loss: 4.1885 - val_accuracy: 0.2741
# Epoch 22/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.9093 - accuracy: 0.6903 - val_loss: 2.5877 - val_accuracy: 0.3926
# Epoch 23/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.8601 - accuracy: 0.7069 - val_loss: 1.8126 - val_accuracy: 0.5056
# Epoch 24/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.8055 - accuracy: 0.7287 - val_loss: 1.1715 - val_accuracy: 0.6278
# Epoch 25/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.7691 - accuracy: 0.7384 - val_loss: 1.8506 - val_accuracy: 0.4444
# Epoch 26/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.7423 - accuracy: 0.7306 - val_loss: 1.1729 - val_accuracy: 0.6463
# Epoch 27/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.7011 - accuracy: 0.7625 - val_loss: 2.0335 - val_accuracy: 0.5148
# Epoch 28/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.7171 - accuracy: 0.7505 - val_loss: 1.2891 - val_accuracy: 0.6093
# Epoch 29/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.6673 - accuracy: 0.7681 - val_loss: 1.3262 - val_accuracy: 0.6093
# Epoch 30/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.7184 - accuracy: 0.7602 - val_loss: 1.5868 - val_accuracy: 0.4778
# Epoch 31/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.6832 - accuracy: 0.7537 - val_loss: 1.2775 - val_accuracy: 0.6315
# Epoch 32/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.6320 - accuracy: 0.7787 - val_loss: 1.7781 - val_accuracy: 0.4870
# Epoch 33/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.6141 - accuracy: 0.7750 - val_loss: 1.7814 - val_accuracy: 0.4556
# Epoch 34/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.6463 - accuracy: 0.7847 - val_loss: 1.7053 - val_accuracy: 0.6037
# Epoch 35/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.6456 - accuracy: 0.7889 - val_loss: 2.1929 - val_accuracy: 0.4278
# Epoch 36/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.6762 - accuracy: 0.7625 - val_loss: 4.8866 - val_accuracy: 0.4426
# Epoch 37/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.6405 - accuracy: 0.7884 - val_loss: 3.8717 - val_accuracy: 0.2685
# Epoch 38/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.6362 - accuracy: 0.7824 - val_loss: 1.4050 - val_accuracy: 0.6944
# Epoch 39/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.5942 - accuracy: 0.7870 - val_loss: 4.1216 - val_accuracy: 0.4111
# Epoch 40/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.5577 - accuracy: 0.8042 - val_loss: 0.9184 - val_accuracy: 0.7093
# Epoch 41/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.4752 - accuracy: 0.8315 - val_loss: 0.9015 - val_accuracy: 0.7019
# Epoch 42/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.4844 - accuracy: 0.8306 - val_loss: 1.0415 - val_accuracy: 0.6907
# Epoch 43/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.4347 - accuracy: 0.8458 - val_loss: 0.8476 - val_accuracy: 0.7000
# Epoch 44/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.4833 - accuracy: 0.8343 - val_loss: 0.8431 - val_accuracy: 0.7130
# Epoch 45/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.4739 - accuracy: 0.8356 - val_loss: 1.8024 - val_accuracy: 0.5259
# Epoch 46/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.4641 - accuracy: 0.8366 - val_loss: 2.3880 - val_accuracy: 0.4722
# Epoch 47/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.4640 - accuracy: 0.8347 - val_loss: 1.1809 - val_accuracy: 0.6315
# Epoch 48/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.4400 - accuracy: 0.8495 - val_loss: 2.5744 - val_accuracy: 0.4519
# Epoch 49/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.4316 - accuracy: 0.8519 - val_loss: 0.7487 - val_accuracy: 0.7741
# Epoch 50/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3541 - accuracy: 0.8764 - val_loss: 1.3078 - val_accuracy: 0.7315
# Epoch 51/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3129 - accuracy: 0.8912 - val_loss: 1.0508 - val_accuracy: 0.7222
# Epoch 52/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3525 - accuracy: 0.8773 - val_loss: 5.2880 - val_accuracy: 0.2352
# Epoch 53/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3458 - accuracy: 0.8917 - val_loss: 1.9847 - val_accuracy: 0.5611
# Epoch 54/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3724 - accuracy: 0.8745 - val_loss: 0.9967 - val_accuracy: 0.7667
# Epoch 55/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3247 - accuracy: 0.8870 - val_loss: 1.9156 - val_accuracy: 0.5852
# Epoch 56/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2964 - accuracy: 0.9014 - val_loss: 1.2337 - val_accuracy: 0.7019
# Epoch 57/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3506 - accuracy: 0.8810 - val_loss: 1.7751 - val_accuracy: 0.5389
# Epoch 58/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3342 - accuracy: 0.8884 - val_loss: 1.7375 - val_accuracy: 0.5574
# Epoch 59/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2654 - accuracy: 0.9194 - val_loss: 1.9690 - val_accuracy: 0.5019
# Epoch 60/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3014 - accuracy: 0.8986 - val_loss: 1.4283 - val_accuracy: 0.6093
# Epoch 61/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2847 - accuracy: 0.9042 - val_loss: 2.0461 - val_accuracy: 0.4870
# Epoch 62/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3476 - accuracy: 0.8815 - val_loss: 3.0865 - val_accuracy: 0.4352
# Epoch 63/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3474 - accuracy: 0.8861 - val_loss: 1.2689 - val_accuracy: 0.6796
# Epoch 64/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3184 - accuracy: 0.8981 - val_loss: 2.9268 - val_accuracy: 0.4667
# Epoch 65/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2869 - accuracy: 0.9060 - val_loss: 0.6016 - val_accuracy: 0.8222
# Epoch 66/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2379 - accuracy: 0.9134 - val_loss: 1.7925 - val_accuracy: 0.5759
# Epoch 67/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2919 - accuracy: 0.9056 - val_loss: 1.1057 - val_accuracy: 0.7167
# Epoch 68/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2382 - accuracy: 0.9171 - val_loss: 1.2296 - val_accuracy: 0.7000
# Epoch 69/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3261 - accuracy: 0.8954 - val_loss: 12.7661 - val_accuracy: 0.2204
# Epoch 70/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.3101 - accuracy: 0.8940 - val_loss: 2.4826 - val_accuracy: 0.3759
# Epoch 71/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2173 - accuracy: 0.9264 - val_loss: 1.3018 - val_accuracy: 0.6722
# Epoch 72/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2665 - accuracy: 0.9116 - val_loss: 1.2950 - val_accuracy: 0.7444
# Epoch 73/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2465 - accuracy: 0.9139 - val_loss: 4.6826 - val_accuracy: 0.3574
# Epoch 74/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2245 - accuracy: 0.9227 - val_loss: 1.3598 - val_accuracy: 0.7000
# Epoch 75/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2547 - accuracy: 0.9134 - val_loss: 2.5408 - val_accuracy: 0.5815
# Epoch 76/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1965 - accuracy: 0.9394 - val_loss: 3.2358 - val_accuracy: 0.4667
# Epoch 77/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2194 - accuracy: 0.9319 - val_loss: 1.2238 - val_accuracy: 0.7130
# Epoch 78/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1913 - accuracy: 0.9403 - val_loss: 1.1009 - val_accuracy: 0.7537
# Epoch 79/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1636 - accuracy: 0.9403 - val_loss: 2.0733 - val_accuracy: 0.6148
# Epoch 80/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1901 - accuracy: 0.9421 - val_loss: 5.3563 - val_accuracy: 0.3981
# Epoch 81/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1561 - accuracy: 0.9444 - val_loss: 0.9176 - val_accuracy: 0.7870
# Epoch 82/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1731 - accuracy: 0.9431 - val_loss: 1.8009 - val_accuracy: 0.6278
# Epoch 83/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1768 - accuracy: 0.9389 - val_loss: 1.5852 - val_accuracy: 0.7111
# Epoch 84/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1205 - accuracy: 0.9569 - val_loss: 0.9367 - val_accuracy: 0.8093
# Epoch 85/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1448 - accuracy: 0.9542 - val_loss: 0.6512 - val_accuracy: 0.8296
# Epoch 86/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1460 - accuracy: 0.9532 - val_loss: 0.8410 - val_accuracy: 0.7870
# Epoch 87/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1402 - accuracy: 0.9574 - val_loss: 0.9560 - val_accuracy: 0.7611
# Epoch 88/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1472 - accuracy: 0.9551 - val_loss: 1.3781 - val_accuracy: 0.7241
# Epoch 89/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2330 - accuracy: 0.9255 - val_loss: 3.4163 - val_accuracy: 0.4481
# Epoch 90/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1533 - accuracy: 0.9463 - val_loss: 1.3129 - val_accuracy: 0.7093
# Epoch 91/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1418 - accuracy: 0.9560 - val_loss: 0.7919 - val_accuracy: 0.8093
# Epoch 92/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2115 - accuracy: 0.9343 - val_loss: 3.7856 - val_accuracy: 0.4481
# Epoch 93/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1734 - accuracy: 0.9458 - val_loss: 1.1057 - val_accuracy: 0.7241
# Epoch 94/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1690 - accuracy: 0.9477 - val_loss: 0.7250 - val_accuracy: 0.8111
# Epoch 95/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1806 - accuracy: 0.9412 - val_loss: 1.3335 - val_accuracy: 0.7556
# Epoch 96/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1819 - accuracy: 0.9412 - val_loss: 2.8503 - val_accuracy: 0.5130
# Epoch 97/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1404 - accuracy: 0.9551 - val_loss: 1.2525 - val_accuracy: 0.6778
# Epoch 98/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.2468 - accuracy: 0.9120 - val_loss: 4.8673 - val_accuracy: 0.3574
# Epoch 99/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1835 - accuracy: 0.9394 - val_loss: 2.2695 - val_accuracy: 0.5981
# Epoch 100/100
# 68/68 [==============================] - 93s 1s/step - loss: 0.1354 - accuracy: 0.9593 - val_loss: 2.6481 - val_accuracy: 0.8259

# %%
metrics = hist.history
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(hist.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.title('Training and Validation Loss')
plt.subplot(1, 2, 2)
plt.plot(hist.epoch, metrics['accuracy'], metrics['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])
plt.title('Training and Validation Accuracy')
plt.show()

# %%
test_files = filenames = tf.io.gfile.glob(str(data_test) + '/*/*.jpg')
test_ds = pre_process(test_files)

# %%
test_images = []
test_labels = []

for image, label in test_ds:
  test_images.append(image.numpy())
  test_labels.append(label.numpy())

test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
y_pred = np.argmax(model.predict(test_images), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Test set accuracy: {test_acc:.0%}')
# Out:
# Test set accuracy: 76%

# %%
model.save('/content/drive/MyDrive/EfficientNetB2_new.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
from tensorflow.contrib import lite
converter = lite.TFLiteConverter.from_keras_model_file( 'model.h5')
tfmodel = converter.convert()
open ("model.tflite" , "wb") .write(tfmodel)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=class_names,
            yticklabels=class_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()
