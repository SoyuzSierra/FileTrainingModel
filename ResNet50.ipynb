# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import cv2
import seaborn as sns
import random
import pathlib

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.applications import ResNet50

# %%
from google.colab import drive
drive._mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/dataset-original.zip" -d "/content/drive/MyDrive"

# %%
strategy = tf.distribute.MirroredStrategy()

print('Number of devices: {}'.format(strategy.num_replicas_in_sync))
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# Number of devices: 1

# %%
base_dir = '/content/drive/MyDrive/trash_dataset'
dataset = pathlib.Path(base_dir)
print(str(dataset))
# Out:
# /content/drive/MyDrive/trash_dataset

# %%
train_dir = str(dataset) + '/train'
test_dir = str(dataset) + '/test'
data_train = pathlib.Path(train_dir)
data_test = pathlib.Path(test_dir)

print(str(data_train))
print(str(data_test))
# Out:
# /content/drive/MyDrive/trash_dataset/train
# /content/drive/MyDrive/trash_dataset/test

# %%
class_names = np.array(tf.io.gfile.listdir(str(data_train)))
class_names = class_names[class_names != '.DS_Store']
print(class_names)
# Out:
# ['paper' 'metal' 'plastic' 'glass' 'trash' 'cardboard']

# %%
batch_size = 32
img_height = 224
img_width = 224

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_train,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2700 files belonging to 6 classes.
# Using 2160 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_train,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2700 files belonging to 6 classes.
# Using 540 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %%
def get_label(file_path):
  parts = tf.strings.split(file_path, os.path.sep)
  one_hot = parts[-2] == class_names
  return tf.argmax(one_hot)

# %%
def get_image(file_path):
  img = tf.io.read_file(file_path)
  img = tf.io.decode_jpeg(img, channels=3)
  img = tf.image.resize(img, [img_height, img_width])
  return img

# %%
def get_img_and_label(file_path):
  label = get_label(file_path)
  img = get_image(file_path)
  return img, label

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomRotation(factor=0.15),
    layers.RandomTranslation(height_factor=0.1, width_factor=0.1),
    layers.RandomFlip(),
    layers.RandomContrast(factor=0.1)
  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
def pre_process(image_files):
  files_ds = tf.data.Dataset.from_tensor_slices(image_files)
  image_ds = files_ds.map(map_func=get_img_and_label, num_parallel_calls=AUTOTUNE)
  return image_ds

# %%
num_classes = len(class_names)
print(num_classes)
# Out:
# 6

# %%
with strategy.scope():
  inputs = layers.Input(shape=(img_height, img_width, 3))
  x = data_augmentation(inputs)
  x = tf.keras.applications.resnet50.preprocess_input(x, data_format=None)
  outputs = ResNet50(include_top=True, weights=None, classes=num_classes)(x)
  model = tf.keras.Model(inputs, outputs)

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

model.summary()
# Out:
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  sequential (Sequential)     (None, 224, 224, 3)       0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  resnet50 (Functional)       (None, 6)                 23600006
#
# =================================================================
# Total params: 23,600,006
# Trainable params: 23,546,886
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
epochs = 100
hist = model.fit(train_ds, 
                 epochs=epochs, 
                 validation_data=val_ds)
# Out:
# Epoch 1/100
# 68/68 [==============================] - 395s 3s/step - loss: 1.9499 - accuracy: 0.4074 - val_loss: 2.3051 - val_accuracy: 0.1833
# Epoch 2/100
# 68/68 [==============================] - 53s 778ms/step - loss: 1.2946 - accuracy: 0.5407 - val_loss: 1.7646 - val_accuracy: 0.3074
# Epoch 3/100
# 68/68 [==============================] - 53s 784ms/step - loss: 1.3218 - accuracy: 0.5310 - val_loss: 2.7719 - val_accuracy: 0.5222
# Epoch 4/100
# 68/68 [==============================] - 53s 782ms/step - loss: 1.2090 - accuracy: 0.5708 - val_loss: 3.0348 - val_accuracy: 0.3593
# Epoch 5/100
# 68/68 [==============================] - 53s 783ms/step - loss: 1.1524 - accuracy: 0.5801 - val_loss: 4.1835 - val_accuracy: 0.4204
# Epoch 6/100
# 68/68 [==============================] - 53s 783ms/step - loss: 1.0931 - accuracy: 0.5991 - val_loss: 1.3969 - val_accuracy: 0.5074
# Epoch 7/100
# 68/68 [==============================] - 53s 783ms/step - loss: 1.0212 - accuracy: 0.6319 - val_loss: 2.2353 - val_accuracy: 0.4630
# Epoch 8/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.9787 - accuracy: 0.6542 - val_loss: 2.6821 - val_accuracy: 0.3130
# Epoch 9/100
# 68/68 [==============================] - 53s 781ms/step - loss: 1.0201 - accuracy: 0.6333 - val_loss: 2.2732 - val_accuracy: 0.4222
# Epoch 10/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.9827 - accuracy: 0.6426 - val_loss: 6.6272 - val_accuracy: 0.2907
# Epoch 11/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.9166 - accuracy: 0.6713 - val_loss: 1.2969 - val_accuracy: 0.5667
# Epoch 12/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.8704 - accuracy: 0.6991 - val_loss: 1.2338 - val_accuracy: 0.5759
# Epoch 13/100
# 68/68 [==============================] - 53s 774ms/step - loss: 0.8093 - accuracy: 0.7079 - val_loss: 2.1526 - val_accuracy: 0.3685
# Epoch 14/100
# 68/68 [==============================] - 52s 769ms/step - loss: 0.7969 - accuracy: 0.7190 - val_loss: 3.2912 - val_accuracy: 0.3833
# Epoch 15/100
# 68/68 [==============================] - 52s 768ms/step - loss: 0.7704 - accuracy: 0.7315 - val_loss: 6.4336 - val_accuracy: 0.4352
# Epoch 16/100
# 68/68 [==============================] - 52s 767ms/step - loss: 0.7763 - accuracy: 0.7111 - val_loss: 1.2657 - val_accuracy: 0.6389
# Epoch 17/100
# 68/68 [==============================] - 52s 767ms/step - loss: 0.7231 - accuracy: 0.7269 - val_loss: 1.7639 - val_accuracy: 0.4796
# Epoch 18/100
# 68/68 [==============================] - 52s 768ms/step - loss: 0.7361 - accuracy: 0.7417 - val_loss: 5.9219 - val_accuracy: 0.3981
# Epoch 19/100
# 68/68 [==============================] - 52s 768ms/step - loss: 0.7445 - accuracy: 0.7343 - val_loss: 1.4992 - val_accuracy: 0.5537
# Epoch 20/100
# 68/68 [==============================] - 52s 768ms/step - loss: 0.6791 - accuracy: 0.7514 - val_loss: 3.7037 - val_accuracy: 0.3759
# Epoch 21/100
# 68/68 [==============================] - 52s 767ms/step - loss: 0.6249 - accuracy: 0.7759 - val_loss: 1.6533 - val_accuracy: 0.4833
# Epoch 22/100
# 68/68 [==============================] - 52s 768ms/step - loss: 0.6306 - accuracy: 0.7699 - val_loss: 1.3595 - val_accuracy: 0.5926
# Epoch 23/100
# 68/68 [==============================] - 52s 768ms/step - loss: 0.5933 - accuracy: 0.7907 - val_loss: 3.4544 - val_accuracy: 0.5278
# Epoch 24/100
# 68/68 [==============================] - 52s 769ms/step - loss: 0.6091 - accuracy: 0.7787 - val_loss: 2.3887 - val_accuracy: 0.5704
# Epoch 25/100
# 68/68 [==============================] - 52s 769ms/step - loss: 0.5553 - accuracy: 0.7986 - val_loss: 2.4336 - val_accuracy: 0.5556
# Epoch 26/100
# 68/68 [==============================] - 52s 769ms/step - loss: 0.5179 - accuracy: 0.8102 - val_loss: 3.4714 - val_accuracy: 0.4074
# Epoch 27/100
# 68/68 [==============================] - 52s 769ms/step - loss: 0.5338 - accuracy: 0.8079 - val_loss: 2.5563 - val_accuracy: 0.4278
# Epoch 28/100
# 68/68 [==============================] - 52s 768ms/step - loss: 0.4755 - accuracy: 0.8264 - val_loss: 1.1069 - val_accuracy: 0.6407
# Epoch 29/100
# 68/68 [==============================] - 52s 768ms/step - loss: 0.5455 - accuracy: 0.7963 - val_loss: 1.9698 - val_accuracy: 0.6907
# Epoch 30/100
# 68/68 [==============================] - 52s 769ms/step - loss: 0.4747 - accuracy: 0.8190 - val_loss: 0.8867 - val_accuracy: 0.7111
# Epoch 31/100
# 68/68 [==============================] - 52s 769ms/step - loss: 0.4339 - accuracy: 0.8394 - val_loss: 0.8732 - val_accuracy: 0.7593
# Epoch 32/100
# 68/68 [==============================] - 52s 768ms/step - loss: 0.4229 - accuracy: 0.8519 - val_loss: 2.4372 - val_accuracy: 0.4556
# Epoch 33/100
# 68/68 [==============================] - 52s 768ms/step - loss: 0.4315 - accuracy: 0.8454 - val_loss: 1.1302 - val_accuracy: 0.6685
# Epoch 34/100
# 68/68 [==============================] - 53s 777ms/step - loss: 0.4199 - accuracy: 0.8458 - val_loss: 6.5782 - val_accuracy: 0.5204
# Epoch 35/100
# 68/68 [==============================] - 53s 783ms/step - loss: 0.4786 - accuracy: 0.8231 - val_loss: 1.3435 - val_accuracy: 0.5704
# Epoch 36/100
# 68/68 [==============================] - 53s 783ms/step - loss: 0.4462 - accuracy: 0.8361 - val_loss: 1.1836 - val_accuracy: 0.6870
# Epoch 37/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.4009 - accuracy: 0.8509 - val_loss: 1.2905 - val_accuracy: 0.6741
# Epoch 38/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.3745 - accuracy: 0.8690 - val_loss: 1.2557 - val_accuracy: 0.6333
# Epoch 39/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.3457 - accuracy: 0.8718 - val_loss: 1.1646 - val_accuracy: 0.7648
# Epoch 40/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.3606 - accuracy: 0.8708 - val_loss: 1.6150 - val_accuracy: 0.6574
# Epoch 41/100
# 68/68 [==============================] - 53s 783ms/step - loss: 0.3463 - accuracy: 0.8782 - val_loss: 1.1887 - val_accuracy: 0.6685
# Epoch 42/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.3442 - accuracy: 0.8801 - val_loss: 1.0316 - val_accuracy: 0.7389
# Epoch 43/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.3928 - accuracy: 0.8671 - val_loss: 1.0474 - val_accuracy: 0.7037
# Epoch 44/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.3858 - accuracy: 0.8574 - val_loss: 4.0630 - val_accuracy: 0.4222
# Epoch 45/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.3492 - accuracy: 0.8718 - val_loss: 1.3964 - val_accuracy: 0.6296
# Epoch 46/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.3264 - accuracy: 0.8819 - val_loss: 1.6610 - val_accuracy: 0.6444
# Epoch 47/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.2940 - accuracy: 0.8926 - val_loss: 0.8405 - val_accuracy: 0.7241
# Epoch 48/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.3038 - accuracy: 0.8981 - val_loss: 1.5705 - val_accuracy: 0.6056
# Epoch 49/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.2724 - accuracy: 0.9097 - val_loss: 0.6688 - val_accuracy: 0.8093
# Epoch 50/100
# 68/68 [==============================] - 53s 780ms/step - loss: 0.3080 - accuracy: 0.8898 - val_loss: 2.2818 - val_accuracy: 0.6426
# Epoch 51/100
# 68/68 [==============================] - 53s 778ms/step - loss: 0.3040 - accuracy: 0.8852 - val_loss: 0.8779 - val_accuracy: 0.7870
# Epoch 52/100
# 68/68 [==============================] - 53s 783ms/step - loss: 0.2718 - accuracy: 0.9037 - val_loss: 0.7815 - val_accuracy: 0.7907
# Epoch 53/100
# 68/68 [==============================] - 53s 783ms/step - loss: 0.2970 - accuracy: 0.9046 - val_loss: 3.5227 - val_accuracy: 0.6278
# Epoch 54/100
# 68/68 [==============================] - 53s 778ms/step - loss: 0.3067 - accuracy: 0.8986 - val_loss: 1.3485 - val_accuracy: 0.6926
# Epoch 55/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.2954 - accuracy: 0.8963 - val_loss: 2.3317 - val_accuracy: 0.5037
# Epoch 56/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.4823 - accuracy: 0.8352 - val_loss: 3.2488 - val_accuracy: 0.6778
# Epoch 57/100
# 68/68 [==============================] - 53s 783ms/step - loss: 0.3451 - accuracy: 0.8958 - val_loss: 4.3683 - val_accuracy: 0.4630
# Epoch 58/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.4047 - accuracy: 0.8639 - val_loss: 3.1047 - val_accuracy: 0.5241
# Epoch 59/100
# 68/68 [==============================] - 53s 779ms/step - loss: 0.2871 - accuracy: 0.8926 - val_loss: 0.9171 - val_accuracy: 0.7593
# Epoch 60/100
# 68/68 [==============================] - 53s 777ms/step - loss: 0.2594 - accuracy: 0.9120 - val_loss: 0.6405 - val_accuracy: 0.7944
# Epoch 61/100
# 68/68 [==============================] - 53s 780ms/step - loss: 0.2007 - accuracy: 0.9301 - val_loss: 0.5670 - val_accuracy: 0.8185
# Epoch 62/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.2153 - accuracy: 0.9287 - val_loss: 2.7363 - val_accuracy: 0.5759
# Epoch 63/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.2783 - accuracy: 0.9042 - val_loss: 1.3183 - val_accuracy: 0.6685
# Epoch 64/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1747 - accuracy: 0.9458 - val_loss: 1.7591 - val_accuracy: 0.6019
# Epoch 65/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.1554 - accuracy: 0.9440 - val_loss: 1.4696 - val_accuracy: 0.7481
# Epoch 66/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.1832 - accuracy: 0.9394 - val_loss: 1.3320 - val_accuracy: 0.7167
# Epoch 67/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1545 - accuracy: 0.9449 - val_loss: 0.7917 - val_accuracy: 0.8111
# Epoch 68/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1923 - accuracy: 0.9282 - val_loss: 0.9154 - val_accuracy: 0.7981
# Epoch 69/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1916 - accuracy: 0.9343 - val_loss: 0.6518 - val_accuracy: 0.7981
# Epoch 70/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.2446 - accuracy: 0.9097 - val_loss: 2.0025 - val_accuracy: 0.6556
# Epoch 71/100
# 68/68 [==============================] - 53s 780ms/step - loss: 0.1915 - accuracy: 0.9398 - val_loss: 1.0847 - val_accuracy: 0.7370
# Epoch 72/100
# 68/68 [==============================] - 55s 805ms/step - loss: 0.1507 - accuracy: 0.9505 - val_loss: 4.0613 - val_accuracy: 0.4259
# Epoch 73/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1264 - accuracy: 0.9509 - val_loss: 3.3760 - val_accuracy: 0.5593
# Epoch 74/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1372 - accuracy: 0.9560 - val_loss: 0.6537 - val_accuracy: 0.8315
# Epoch 75/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1138 - accuracy: 0.9579 - val_loss: 1.1164 - val_accuracy: 0.7685
# Epoch 76/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.2495 - accuracy: 0.9134 - val_loss: 1.3414 - val_accuracy: 0.7426
# Epoch 77/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.2595 - accuracy: 0.9120 - val_loss: 0.6679 - val_accuracy: 0.8185
# Epoch 78/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1423 - accuracy: 0.9468 - val_loss: 0.5235 - val_accuracy: 0.8537
# Epoch 79/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1267 - accuracy: 0.9546 - val_loss: 0.7952 - val_accuracy: 0.8000
# Epoch 80/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1965 - accuracy: 0.9338 - val_loss: 0.7810 - val_accuracy: 0.7944
# Epoch 81/100
# 68/68 [==============================] - 53s 778ms/step - loss: 0.1076 - accuracy: 0.9593 - val_loss: 0.6090 - val_accuracy: 0.8481
# Epoch 82/100
# 68/68 [==============================] - 53s 783ms/step - loss: 0.1050 - accuracy: 0.9606 - val_loss: 0.8715 - val_accuracy: 0.8167
# Epoch 83/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.1175 - accuracy: 0.9616 - val_loss: 1.0839 - val_accuracy: 0.7222
# Epoch 84/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.1197 - accuracy: 0.9616 - val_loss: 0.8555 - val_accuracy: 0.8019
# Epoch 85/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1615 - accuracy: 0.9426 - val_loss: 1.1144 - val_accuracy: 0.7204
# Epoch 86/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1765 - accuracy: 0.9403 - val_loss: 1.3276 - val_accuracy: 0.7833
# Epoch 87/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.0750 - accuracy: 0.9745 - val_loss: 0.6398 - val_accuracy: 0.8352
# Epoch 88/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.0927 - accuracy: 0.9667 - val_loss: 2.4037 - val_accuracy: 0.6630
# Epoch 89/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.2119 - accuracy: 0.9310 - val_loss: 1.2849 - val_accuracy: 0.7111
# Epoch 90/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1211 - accuracy: 0.9560 - val_loss: 0.7941 - val_accuracy: 0.8000
# Epoch 91/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.0694 - accuracy: 0.9759 - val_loss: 0.7346 - val_accuracy: 0.8278
# Epoch 92/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.0592 - accuracy: 0.9829 - val_loss: 0.5517 - val_accuracy: 0.8667
# Epoch 93/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.0999 - accuracy: 0.9667 - val_loss: 0.8612 - val_accuracy: 0.7907
# Epoch 94/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1371 - accuracy: 0.9597 - val_loss: 1.0446 - val_accuracy: 0.7944
# Epoch 95/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1282 - accuracy: 0.9528 - val_loss: 2.0876 - val_accuracy: 0.6648
# Epoch 96/100
# 68/68 [==============================] - 53s 781ms/step - loss: 0.1536 - accuracy: 0.9495 - val_loss: 1.0844 - val_accuracy: 0.7389
# Epoch 97/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.0769 - accuracy: 0.9722 - val_loss: 0.7921 - val_accuracy: 0.8093
# Epoch 98/100
# 68/68 [==============================] - 53s 783ms/step - loss: 0.0638 - accuracy: 0.9801 - val_loss: 1.1430 - val_accuracy: 0.7963
# Epoch 99/100
# 68/68 [==============================] - 53s 782ms/step - loss: 0.0809 - accuracy: 0.9736 - val_loss: 6.1600 - val_accuracy: 0.5685
# Epoch 100/100
# 68/68 [==============================] - 53s 783ms/step - loss: 0.0854 - accuracy: 0.9713 - val_loss: 0.9139 - val_accuracy: 0.8111

# %%
metrics = hist.history
plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(hist.epoch, metrics['loss'], metrics['val_loss'])
plt.legend(['loss', 'val_loss'])
plt.title('Training and Validation Loss')
plt.subplot(1, 2, 2)
plt.plot(hist.epoch, metrics['accuracy'], metrics['val_accuracy'])
plt.legend(['accuracy', 'val_accuracy'])
plt.title('Training and Validation Accuracy')
plt.show()

# %%
test_files = filenames = tf.io.gfile.glob(str(data_test) + '/*/*.jpg')
test_ds = pre_process(test_files)

# %%
test_images = []
test_labels = []

for image, label in test_ds:
  test_images.append(image.numpy())
  test_labels.append(label.numpy())

test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
model_Resnet50 = tf.keras.models.load_model('/content/drive/MyDrive/ResNet50_new.h5')

# %%
loss, acc = model_Resnet50.evaluate(test_images, test_labels)
print('Restored model, accuracy: {:5.0f}%'.format(100 * acc))
# Out:
# 20/20 [==============================] - 14s 234ms/step - loss: 1.1946 - accuracy: 0.7873
# Restored model, accuracy:    79%

# %%
from sklearn.metrics import classification_report

y_pred = np.argmax(model_Resnet50.predict(test_images), axis=1)
y_true = test_labels

print(classification_report(y_true, y_pred, target_names=class_names))
# Out:
#               precision    recall  f1-score   support
#
#    cardboard       0.86      0.87      0.87       101
#        glass       0.77      0.78      0.77       125
#        metal       0.88      0.58      0.70       102
#        paper       0.77      0.91      0.84       148
#      plastic       0.72      0.81      0.76       120
#        trash       0.77      0.59      0.67        34
#
#     accuracy                           0.79       630
#    macro avg       0.80      0.76      0.77       630
# weighted avg       0.79      0.79      0.78       630

# %%
import sklearn.metrics as skm

cm = skm.multilabel_confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# [[[515  14]
#   [ 13  88]]
#
#  [[476  29]
#   [ 28  97]]
#
#  [[520   8]
#   [ 43  59]]
#
#  [[442  40]
#   [ 13 135]]
#
#  [[473  37]
#   [ 23  97]]
#
#  [[590   6]
#   [ 14  20]]]

# %%
y_pred = np.argmax(model.predict(test_images), axis=1)
y_true = test_labels

test_acc = sum(y_pred == y_true) / len(y_true)
print(f'Test set accuracy: {test_acc:.0%}')
# Out:
# Test set accuracy: 79%

# %%
model.save('/content/drive/MyDrive/ResNet50_new.h5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
from tensorflow.contrib import lite
converter = lite.TFLiteConverter.from_keras_model_file( 'model.h5')
tfmodel = converter.convert()
open ("model.tflite" , "wb") .write(tfmodel)

# %%
confusion_mtx = tf.math.confusion_matrix(y_true, y_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(confusion_mtx,
            xticklabels=class_names,
            yticklabels=class_names,
            annot=True, fmt='g')
plt.xlabel('Prediction')
plt.ylabel('Label')
plt.show()
